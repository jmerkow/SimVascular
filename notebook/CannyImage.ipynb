# %%
import SimpleITK as sitk
import numpy as np
import sys,os
# %matplotlib inline

# %%
filelistfile='/home/AD/jmerkow/Code/StructuredForest3d/cvpr-test/image-name-full.txt'
with open(filelistfile, 'r') as f:
    files= [line.strip() for line in f]
files
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-aa8144978a42> in <module>()
#       1 filelistfile='/home/AD/jmerkow/Code/StructuredForest3d/cvpr-test/image-name-full.txt'
# ----> 2 with open(filelistfile, 'r') as f:
#       3     files= [line.strip() for line in f]
#       4 files
#
# IOError: [Errno 2] No such file or directory: '/home/AD/jmerkow/Code/StructuredForest3d/cvpr-test/image-name-full.txt'

# %%
outputdir='/home/AD/jmerkow/Dropbox/Data/I2IResults/3DImages_canny'
if not os.path.exists(outputdir):
